# %%
import pandas as pd
import numpy as np
# creating a dictonary for color code 
color_dict = {1:'Red',2:'Green',3:'Blue',4:'Yellow',5:'Orange',6:'Purple',7:'Pink',8:'Bown',9:'Golden'}
#print(color_dict)
def Master_mind_logic(code_number,obj2,guess_element):
    flag = 0
    #search_element = '2'
    if  code_number == 4:
        code_list_4 = ['1234','5678','6324','4321','9732']
        print("List inside function",code_list_4)
        length = len(code_list_4[0])
        print("check the digit of the code",length)
        #convert into integer
        digit_four = int(code_list_4[0])
        print("int code",digit_four)
        list_data=list(str(digit_four))
        #seprate the int data into list 
        print("Data is of four digit code !!!",list_data)
        for i in list_data:
            if i == guess_element:
                print("Element found in the code")
                flag = flag+1
                print("flag value inside the function",flag)
            else:
                print("Element not found in the code")
        if(flag == 0):
            return 0
        else:
            return 1       
    elif code_number == 3:
        code_list_3 = ['543','456','743','182']
        print("List inside function",code_list_3)
        length = len(code_list_3[0])
        print("check the digit of the code",length)  
          #convert into integer
        digit_three_code = int(code_list_3[0])
        print("int code",digit_three_code)
        list_data=list(str(digit_three_code))
        #seprate the int data into list 
        print("Data is of four digit code !!!",list_data)
        for i in list_data:
            if i == guess_element:
                print("Element found in the code")
                flag = flag+1
                print("flag value inside the function",flag)
            else:
                print("Element not found in the code")
        if(flag == 0):
            return 0
        else:
            return 1
    elif code_number == 2:     
        code_list_2 = ['28','74','96','68']
        print("List inside function",code_list_2)
        length = len(code_list_2[0])
        print("check the digit of the code",length)
          #convert into integer
        digit_two_code = int(code_list_2[0])
        print("int code",digit_two_code)
        list_data=list(str(digit_two_code))
        #seprate the int data into list 
        print("Data is of two digit code !!!",list_data)
        for i in list_data:
            if i == guess_element:
                print("Element found in the code")
                flag = flag+1
                print("flag value inside the function",flag)
            else:
                print("Element not found in the code")
        if(flag == 0):
            return 0
        else:
            return 1
    print("Color inside Dictonary",obj2)
    
Guess_vector=np.array([[6,4],[5,3],[4,2]])
print("Guess_vectors are \n",Guess_vector)
Possible_code=np.array([[360],[60],[12]])
print("Possible_codes are \n",Possible_code)
#calling a function
list_color = ['1','2','3','4','5','6','7','8','9']
print("The element which we are searching is\n",list_color[3])
Return_value=Master_mind_logic(4,color_dict,list_color[3])
print("Return value of function",Return_value)
if(Return_value==1):
    print("!!!!COLOR CODE FOUND ENJOY !!!!")
else:
    print("COLOR CODE NOT FOUND PLEASE RETRY AGAIN OOPS")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
retry = 10
print("We have %d retry",retry)
hours = int(input("Enter the hour hand of the clock"))
minutes = int(input("Enter the minute hand of the clock"))
seconds = int(input("Enter the second hand of the clock"))
while retry >0:
    if hours>23 or minutes>59 or seconds>59:
        hours = int(input("Enter the hour hand of the clock"))
        minutes = int(input("Enter the minute hand of the clock"))
        seconds = int(input("Enter the second hand of the clock"))
        retry = retry -1
    else:
        print("Input hour hand enter is",hours)
        print("Input minute hand is",minutes)
        print("Input second hand of the clock",seconds)
        retry = 0
Time= np.array([hours,minutes,seconds])
print("Time value is\n",Time)
# Out:
# We have %d retry 10
# Enter the hour hand of the clock11
# Enter the minute hand of the clock11
# Enter the second hand of the clock11
# Input hour hand enter is 11
# Input minute hand is 11
# Input second hand of the clock 11
# Time value is
#  [11 11 11]
