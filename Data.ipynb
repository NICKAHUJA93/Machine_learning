# %%
#Below are the steps need to perform data analysis on given datasets
#Gathering or collecting of the data
#Cleaning a data(Removing noise,duplicate rows or NAN value if exist) 
#Performing analysis of the data(mean,min,max,mode,medium value)
#Plot the results using matplotlib,seaborn visualization library
#Communicate the insights with client or management 
#Futher classic ml model can be applied as well as feature Engineering and cross validation can be done.
import pandas as pd
import numpy as nm
import matplotlib.pyplot as mat
import seaborn as sns
csv_path ="E:\data.csv"

#Read the csv file and convert into pandas 
data = pd.read_csv(csv_path)
#print complete data set
#print (data)

#display first 10 row
print("!!!.....head data....!!!",data.head(10))

#display last 10 row
print("!!!....tail data ...!!!",data.tail(10))
#Replace all NAN value if there is any NAN value exist in dataset
data=data.duplicated()
print("data after removing duplicate row",data)
#Replace the nan value with zero
data = data.fillna(0)
print("data are mention below",data)
#shape of data
shape = data.shape
print("Shape of data",shape)

#decription of the data
description = data.describe()
print("description of data",description)


print("information of the data",data.info())

label = data['label']
print(label)
#This will filter the data from the Data frame 
data_c =data.iloc[:, 2:211]
print("data from column........!!",data_c)

#Find maximum value of each column
maximum=data_c.max()
print("Maximum data in each column",maximum)
list_value =range(0,208)
mat.pie(list_values,labels=None,autopct='%0.1f%%',shadow=False,startangle=90)
mat.show()

#Find minimum value in each column
minimum =data_c.min()
print("Minimum data in each column",minimum)
data1=sns.lmplot(x="id",y="minimum value",data =minimum,order = 2, ci = None)

#Find mean of each column
mean_data =data_c.mean()
print("Mean data in each column",mean_data)
data2=sns.lmplot(x="id",y="mean value",data =mean_data,order = 2, ci = None)

#Find median of each column
median_data =data_c.median()
print("Median data in each column",median_data)
data3=sns.lmplot(x="id",y="medium value",data =medium_data,order = 2, ci = None)

#Find mode in each colum
mode_data = data_c.mode()
print("Mode of data in each column",mode_data)
data4=sns.lmplot(x="id",y="mode_data",data =mode_data,order = 2, ci = None)
# Out:
# !!!.....head data....!!!    id  label           0           1           2           3           4  \
# 0   0      1  269.909900  245.022455  236.823653  236.054239  226.653206
# 1   1      0  268.835447  255.128640  246.701954  242.036672  233.909313
# 2   2      1  249.814868  238.143049  225.509790  224.020928  221.349896
# 3   3      1  265.645330  254.075815  244.410179  237.205829  228.199419
# 4   4      1  252.877477  242.643030  234.194391  230.216435  224.971707
# 5   5      0  269.007832  256.340300  243.373009  244.973729  236.217629
# 6   6      1  257.134605  245.554606  238.301205  233.584067  226.839904
# 7   7      0  264.421179  254.825260  247.305526  236.258199  232.487453
# 8   8      1  262.443435  242.482184  235.243081  229.671630  220.534840
# 9   9      1  272.477025  255.862125  247.440610  237.717413  229.176902
#
#             5           6           7  ...        199        200        201  \
# ...
