# %%
import numpy as nm
import pandas as pd
import matplotlib.pyplot as mat
path = 'E:\Data_Science\Batsman_data.csv'
data = pd.read_csv(path)
print(data)
# clean the data 
#display first five row
#print('data head ...........!!!!!!\n',data.head())
#display last five row
#print('data tail............!!!!!!\n',data.tail(2))
game = data[['Ground','Opposition']]
groud_data = data['Ground']
Opposition_data = data['Opposition']
#print(game)
#Find the match which is played in delhi 
#if Implace == True it will make change in original data

data1 = data[data['Ground'] == 'Delhi']
#print(data1)
# Find a match information  of MS Dhoni played in delhi
#data = data.reset_index(drop=True)
data2 = data[(data['Ground'] == 'Delhi') & (data['Player_ID'] == 28081)]
print(data2)
mat.figure(1)
mat.plot(groud_data[0:10],Opposition_data[0:10])

mat.plot()

#data_random = data_random.reset_index(drop=True)
#a[(a['some_column']==some_number) and (a['some_other_column']==some_other_number)]
# Out:
#        Unnamed: 0  Bat1 Runs  BF      SR 4s 6s      Opposition         Ground  \
# 0               1   DNB    -   -       -  -  -         v India         Nagpur
# 1               2   DNB    -   -       -  -  -         v India        Kolkata
# 2               3   DNB    -   -       -  -  -         v India          Delhi
# 3               4   DNB    -   -       -  -  -    v Bangladesh          Dhaka
# 4               5   DNB    -   -       -  -  -         v India          Dhaka
# 5               6    0*    0   8    0.00  0  0         v India          Dhaka
# 6               7    0*    0   0       -  0  0       v England       The Oval
# 7               8   DNB    -   -       -  -  -       v England          Leeds
# 8               9   DNB    -   -       -  -  -       v England         Lord's
# 9              10    1*    1   3   33.33  0  0       v England     Nottingham
# 10             11    0*    0   2    0.00  0  0     v Australia      Pallekele
# ...
